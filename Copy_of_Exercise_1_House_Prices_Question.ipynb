# %% [markdown]
# In this exercise you'll try to build a neural network that predicts the price of a house according to a simple formula.
#
# So, imagine if house pricing was as easy as a house costs 50k + 50k per bedroom, so that a 1 bedroom house costs 100k, a 2 bedroom house costs 150k etc.
#
# How would you create a neural network that learns this relationship so that it would predict a 7 bedroom house as costing close to 400k etc.
#
# Hint: Your network might work better if you scale the house price down. You don't have to give the answer 400...it might be better to create something that predicts the number 4, and then your answer is in the 'hundreds of thousands' etc.

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras #keras is an API in TesorFlow
model =keras.Sequential([keras.layers.Dense(units=1,input_shape=[1])]) #keras.leyers define number of input layer,units define nuerons in layer , input_shape define how many inputs are getting
model.compile(optimizer='sgd',loss='mean_squared_error') #using stohastic gradient descent with loss function mean squared error
xs = np.asarray([1,2,3,4,5,8,9,11,12])
ys = np.asarray([100,150,200,250,300,450,500,600,650])

model.fit(xs,ys,epochs=500) #epochs mean 500 iterations over this input
print(model.predict([7.0]))
# Out:
# Epoch 1/500
# 9/9 [==============================] - 0s 7ms/sample - loss: 159454.1875
# Epoch 2/500
# 9/9 [==============================] - 0s 454us/sample - loss: 882.8784
# Epoch 3/500
# 9/9 [==============================] - 0s 180us/sample - loss: 513.9152
# Epoch 4/500
# 9/9 [==============================] - 0s 183us/sample - loss: 507.4882
# Epoch 5/500
# 9/9 [==============================] - 0s 255us/sample - loss: 501.9534
# Epoch 6/500
# 9/9 [==============================] - 0s 201us/sample - loss: 496.4796
# Epoch 7/500
# 9/9 [==============================] - 0s 214us/sample - loss: 491.0667
# Epoch 8/500
# 9/9 [==============================] - 0s 193us/sample - loss: 485.7123
# Epoch 9/500
# 9/9 [==============================] - 0s 248us/sample - loss: 480.4164
# Epoch 10/500
# 9/9 [==============================] - 0s 193us/sample - loss: 475.1781
# Epoch 11/500
# 9/9 [==============================] - 0s 247us/sample - loss: 469.9969
# Epoch 12/500
# ...
